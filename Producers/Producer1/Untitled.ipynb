# %%
import os
from kafka import KafkaConsumer
import json

# %%
cloud_boostrap_server_address1 = "b-1.demo-cluster-1.9q7lp7.c1.kafka.eu-west-1.amazonaws.com:9092"

# %%
TOPIC_NAME = "test_topic_dan"

# %%
consumer = KafkaConsumer(
       TOPIC_NAME,
        bootstrap_servers=cloud_boostrap_server_address1,
        auto_offset_reset='latest',
        group_id="consumer-group-a")

# %%
for msg in consumer:
        print("Registered User = {}".format(json.loads(msg.value)))
# Out:
# Registered User = 100
# Registered User = 13
# Registered User = 36
# Registered User = 96
# Registered User = 72
# Registered User = 50
# Registered User = 61
# Registered User = 39
# Registered User = 6
# Registered User = 18
# Registered User = 32
# Registered User = 50
# Registered User = 16
# Registered User = 37
# Registered User = 86
# Registered User = 7
# Registered User = 5
# Registered User = 6
# Registered User = 57
# Registered User = 47
# Registered User = 5
# Registered User = 33
# Registered User = 25
# Registered User = 27
# Registered User = 68
# Registered User = 25
# Registered User = 11
# Registered User = 72
# Registered User = 21
# Registered User = 27
# Registered User = 78
# Registered User = 22
# Registered User = 72
# Registered User = 22
# Registered User = 86
# Registered User = 66
# Registered User = 23
# Registered User = 88
# Registered User = 49
# Registered User = 70
# Registered User = 86
# Registered User = 72
# Registered User = 75
# Registered User = 28
# Registered User = 26
# Registered User = 64
# Registered User = 9
# Registered User = 59
# Registered User = 64
# Registered User = 16
# Registered User = 1
# Registered User = 50
# Registered User = 10
# Registered User = 55
# Registered User = 98
# Registered User = 52
# Registered User = 78
# Registered User = 80
# Registered User = 82
# Registered User = 74
# Registered User = 91
# Registered User = 92
# Registered User = 4
# Registered User = 2
# Registered User = 18
# Registered User = 69
# Registered User = 27
# Registered User = 85
# Registered User = 64
# Registered User = 20
# Registered User = 18
# Registered User = 51
# Registered User = 22
# Registered User = 94
# Registered User = 86
# Registered User = 90
# Registered User = 95
# Registered User = 6
# Registered User = 20
# Registered User = 68
# Registered User = 13
# Registered User = 67
# Registered User = 98
# Registered User = 44
# Registered User = 23
# Registered User = 60
# Registered User = 81
# Registered User = 52
# Registered User = 11
# Registered User = 32
# Registered User = 71
# Registered User = 93
# Registered User = 69
# Registered User = 41
# Registered User = 6
# Registered User = 67
# Registered User = 73
# Registered User = 34
# Registered User = 47
# Registered User = 93
# Registered User = 39
# Registered User = 29
# Registered User = 19
# Registered User = 71
# Registered User = 100
# Registered User = 26
# Registered User = 31
# Registered User = 20
# Registered User = 25
# Registered User = 46
# Registered User = 55
# Registered User = 85
# Registered User = 37
# Registered User = 69
# Registered User = 25
# Registered User = 6
# Registered User = 29
# Registered User = 36
# Registered User = 64
# Registered User = 68
# Registered User = 61
# Registered User = 100
# Registered User = 65
# Registered User = 23
# Registered User = 95
# Registered User = 7
# Registered User = 49
# Registered User = 63
# Registered User = 99
# Registered User = 6
# Registered User = 41
# Registered User = 61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26067/1788840444.py in <module>
# ----> 1 for msg in consumer:
#       2         print("Registered User = {}".format(json.loads(msg.value)))
#
# ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# ~/.local/lib/python3.9/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# ~/.local/lib/python3.9/site-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /opt/miniconda/lib/python3.9/selectors.py in select(self, timeout)
#     467             ready = []
#     468             try:
# --> 469                 fd_event_list = self._selector.poll(timeout, max_ev)
#     470             except InterruptedError:
#     471                 return ready
#
# KeyboardInterrupt:
